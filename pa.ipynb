# %% [markdown]
# Aula 01

# %%
# Input Num
idade = 25
print(idade)
altura = 1.75
nuumero_complexo = 2 + 3j

# text
nome = 'joao'

#bool
esta_chovendo = False
# Out:
# 25

# %% [markdown]
# Aula 02

# %% [markdown]
# Algoritmo de calcula o quadrado
#
# # Entrada
#  Ler o Dado
#
# # Processamento
#  multiplica o lado pelo lado
#
# # Saida
#  Mostrar resultado

# %%
# Entrada
lado = 6

# Processamento
quadrado = lado * lado

# Saida
print(f" total da area do quadrado: {quadrado}")
# Out:
#  total da area do quadrado: 36

# %%
#Area
tamanho = float(input("Digite o tamanho da sala em metros: "))
comprimento = float(input("Digite o comprimento da sala em metros: "))
area = tamanho * comprimento
print(f"A área da sala é: {area} metros quadrados")
# Out:
# Digite o tamanho da sala em metros: 423
# Digite o comprimento da sala em metros: 67
# A área da sala é: 28341.0 metros quadrados

# %% [markdown]
# escrever um algoritmo que recebe 04 notas e calcula a media e exibe a media

# %%
# Media de 04 Notas
nome = input("Digite o nome do aluno: ")
n1 = float(input("Digite a primeira nota: "))
n2 = float(input("Digite a segunda nota: "))
n3 = float(input("Digite a terceira nota: "))
n4 = float(input("Digite a quarta nota: "))
md = (n1 + n2 + n3 + n4 ) / 4
print(f'A media do aluno {nome} é: {md}')
# Out:
# Digite o nome do aluno: silva
# Digite a primeira nota: 10
# Digite a segunda nota: 8
# Digite a terceira nota: 7
# Digite a quarta nota: 9
# A media do aluno silva é: 8.5

# %%
# Dobro de Um Numero
num = float(input("Digite um numero: "))
dob = num * 2
print(f"O Dobro do numero selecionado é: {dob}")
# Out:
# Digite um numero: 2.4
# O Dobro do numero selecionado é: 4.8

# %% [markdown]
# Aula 03

# %%
#Area com input

#entrada
tamanho = float(input("Digite o tamanho da sala em metros: "))
comprimento = float(input("Digite o comprimento da sala em metros: "))

#Processamento
area = tamanho * comprimento

#saida
5
print(f"A área da sala é: {area} metros quadrados")
# Out:
# Digite o tamanho da sala em metros: 5
# Digite o comprimento da sala em metros: 5
# A área da sala é: 25.0 metros quadrados

# %%
# Fazer um cadastro simples

#entrada - nome e idade
print('--------Cadastro de Usuario--------')
nome = str (input("Digite seu nome: "))
idade = int(input("Digite sua idade: "))
print("")

#processamento - armazenar dados


#saida - mensagem de boas vindas
print('-----------BEM VINDO-----------')
print(f"Ola {nome}, Seja Bem Vindo!!!!")
print(f"Você tem {idade} anos!")
# Out:
# --------Cadastro de Usuario--------
# Digite seu nome: Silva
# Digite sua idade: 15
#
# -----------BEM VINDO-----------
# Ola Silva, Seja Bem Vindo!!!!
# Você tem 15 anos!

# %%
#Entrada
print('--------ENTRADA D]A TEMPERATURA--------')
celcius = float(input("Digite a temperatura em graus Celcius: "))

#Processamento
fahrenheit = (celcius * 1.8) + 32
print('')

#Saida
print('--------CONVERSÃO--------')
print(f"A temperatura em Fahrenheit é: {fahrenheit}")
# Out:
# --------ENTRADA D]A TEMPERATURA--------
# Digite a temperatura em graus Celcius: 25
#
# --------CONVERSÃO--------
# A temperatura em Fahrenheit é: 77.0

# %%
# Operadores aritimeticos

# Entrada
a = int(input("Digite o primeiro numero: "))
b = int(input("Digite o segundo numero: "))

# Processamento
soma = a + b
subtracao = a - b
multiplicacao = a * b
divisao = a / b
resto = a % b

#Soma de dois numeros
print('')
print('--------SOMA--------')
print('')
print(f'A soma de {a} e {b} é: {soma}')
print('')
print('--------------------')

#Subtração de dois numeros
print('')
print('--------SUBTRAÇÃO--------')
print('')
print(f'A diferença de {a} - {b} é: {subtracao}')
print('')
print('-------------------------')

#Multiplicação de dois numeros
print('')
print('--------MULTIPLICAÇÃO--------')
print('')
print(f'A multiplicação de {a} x {b} é: {multiplicacao}')
print('')
print('-----------------------------')

#Divisão de dois numeros
print('')
print('--------Divisão--------')
print('')
print(f'A divisão de {a} / {b} é: {divisao}')
print('')
print('-----------------------')

#Resto de dois numeros
print('')
print('--------RESTO--------')
print('')
print(f'O resto de {a} e {b} é: {resto}')
print('')
print('---------------------')
# Out:
# Digite o primeiro numero: 5
# Digite o segundo numero: 5
#
# --------SOMA--------
#
# A soma de 5 e 5 é: 10
#
# --------------------
#
# --------SUBTRAÇÃO--------
#
# A diferença de 5 - 5 é: 0
#
# -------------------------
#
# --------MULTIPLICAÇÃO--------
#
# A multiplicação de 5 x 5 é: 25
#
# -----------------------------
#
# --------Divisão--------
#
# A divisão de 5 / 5 é: 1.0
#
# -----------------------
#
# --------RESTO--------
#
# O resto de 5 e 5 é: 0
#
# ---------------------

# %%
#Entrada

n1 = int(input("Digite a primeira nota: "))
n2 = int(input("Digite a segunda nota: "))

#Processamento

igual = n1 == n2
diferente = n1 != n2
maior = n1 > n2
menor = n1 < n2
menor_igual = n1 <= n2
maior_igual = n1 >= n2


#saida

print(igual)
print(diferente)
print(maior)
print(menor)
print(menor_igual)
print(maior_igual)
# Out:
# Digite a primeira nota: 5
# Digite a segunda nota: 5
# True
# False
# False
# False
# True
# True

# %% [markdown]
# Aula 04

# %%
a = int(input("Digite o primeiro numero: "))
b = int(input("Digite o segundo numero: "))

if a > b:
    print(f"{a} é maior que {b}")
else:
    print(f"{b} é maior que {a}")
# Out:
# Digite o primeiro numero: 1
# Digite o segundo numero: 2
# 2 é maior que 1

# %%
# escrever um programa que verifica se o usuario é maior de idade

i = int(input("Digite sua idade: "))

if i >= 18:
    print("Você é maior de idade")
else:
    print("Você é menor de idade")
# Out:
# Digite sua idade: 2313436352154665495941
# Você é maior de idade

# %%
# faça um progtrama que verifica se um numero é par ou impar

num1 = int(input("Digite um numero: "))
calc = num1 % 2

if calc == 0:
    print(f"O numero {num1} é par")
else:
    print(f"O numero {num1} é impar")
# Out:
# Digite um numero: 4
# O numero 4 é par

# %%
# verificação de senha

senhac = int("1234")
senha = int(input("Digite sua senha: "))

if senha == senhac:
    print("Acesso permitido")
else:
    print("Senha incoreta, tente novamente")
    senha = int(input("Digite sua senha: "))

    if senha == senhac:
        print("Acesso permitido")
    else:
        print("Senha incoreta, tente novamente")
        senha = int(input("Digite sua senha: "))

        if senha == senhac:
            print("Acesso permitido")
        else:
            print("Senha incoreta.")
# Out:
# Digite sua senha: 1234
# Acesso permitido

# %%
# numero maior que 10

nu = int(input("Digite um numero: "))

if nu > 10:
    print('O numero é maior que 10')
elif nu == 10:
    print('O numero é igual a 10')
else:
    print('O numero é menor que 10')
# Out:
# Digite um numero: 12
# O numero é maior que 10

# %%
# compra c0om desconto

comp = float(input("Digite o valor da compra: "))

if comp > 100:
    calc = comp - (comp * 0.10)
    print(f"O valor da compra com desconto é: {calc}")
else:
    print(f"O valor da compra é: {comp}")
# Out:
# Digite o valor da compra: 123
# O valor da compra com desconto é: 110.7

# %%
# Aprovado ou reprovado

n1 = float(input("Digite a primeira nota: "))
n2 = float(input("Digite a segunda nota: "))
n3 = float(input("Digite a terceira nota: "))
n4 = float(input("Digite a quarta nota: "))

calc = (n1 + n2 + n3 + n4) / 4

if calc >= 5:
  print(f"Você foi Aprovado com a nota: {calc}")

else:
  print(f"Você foi Reprovado comn a nota: {calc}")
# Out:
# Digite a primeira nota: 8
# Digite a segunda nota: 5
# Digite a terceira nota: 2
# Digite a quarta nota: 9
# Você foi Aprovado com a nota: 6.0

# %% [markdown]
# Aula 05

# %%
#30/03
#Escrever um programa que realiza todas as operações aritimeticas

print("---------CALCULADORA SIMPLES--------")
print("")
print("----------------MENU----------------")
print("")
print("SOMA ----------------------------- 1")
print("")
print("SUBTRAÇÃO ------------------------ 2")
print("")
print("MULTIPLICAÇÃO -------------------- 3")
print("")
print("DIVISÃO -------------------------- 4")
print("------------------------------------")

esc = int(input("Digite a opção desejada: "))

if esc == 1:
    n1 = int(input("selecione o primeiro numero da soma: "))
    n2 = int(input("selecione o segundo numero da soma: "))
    calc = n1 + n2
    print(f"O resultado da Soma é: {calc}")

if esc == 2:
    n1 = int(input("selecione o primeiro numero da subtração:  "))
    n2 = int(input("selecione o segundo numero da subtração: "))
    calc = n1 - n2
    print(f"O resultado da Subtração é: {calc}")

if esc == 3:
    n1 = int(input("selecione o primeiro numero da multiplicação: "))
    n2 = int(input("selecione o segundo numero da multiplicação: "))
    calc = n1 * n2
    print(f"O resultad oda Multiplicação é: {calc}")

if esc == 4:
    n1 = int(input("selecione o primeiro numero da divisão: "))
    n2 = int(input("selecione o segundo numero da divisão: "))
    calc = n1 / n2
    print(f"O resultado da Divisão é: {calc}")
# Out:
# ---------CALCULADORA SIMPLES--------
#
# ----------------MENU----------------
#
# SOMA ----------------------------- 1
#
# SUBTRAÇÃO ------------------------ 2
#
# MULTIPLICAÇÃO -------------------- 3
#
# DIVISÃO -------------------------- 4
# ------------------------------------
# Digite a opção desejada: 4
# selecione o primeiro numero da divisão: 4
# selecione o segundo numero da divisão: 2
# O resultado da Divisão é: 2.0

# %%
# Programa que classifica os tipos de triangulos:
#isoceles
#equilarero
#Escaleno

l1 = int(input("Digite o primeiro lado do triangulo: "))
l2 = int(input("Digite o segundo lado do triangulo: "))
l3 = int(input("Digite o terceiro lado do triangulo: "))

if l1 == l2 and l2 == l3:
    print("O triangulo é equilatero")

if l1 != l2 and l2 != l3 and l1 != l3:
    print("O triangulo é escaleno")

if (l1 == l2 or l2 == l3 or l1 == l3) and (l1 != l2 or l2 != l3 or l1 != l3):
    print("O triangulo é isoceles")
# Out:
# Digite o primeiro lado do triangulo: 2
# Digite o segundo lado do triangulo: 2
# Digite o terceiro lado do triangulo: 6
# O triangulo é isoceles
